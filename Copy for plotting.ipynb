# %% [markdown]
# # EDA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")

# %%
len(df)
# Out:
# 114000

# %%
len(df.columns)
# Out:
# 21

# %%
df.popularity.mean()
# Out:
# 33.2385350877193

# %%
df.shape
# Out:
# (114000, 19)

# %%
df.columns
# Out:
# Index(['artists', 'album_name', 'track_name', 'popularity', 'duration_ms',
#        'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino  \
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name
# 0                                             Comedy  \
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit
# 0                      Comedy          73       230666     False  \
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.drop(columns = ['Unnamed: 0', 'track_id'], inplace = True)

# %%
# Some insights from the pairplot:

# Danceability:
# Danceability seems to be highest for middle tempo songs
# Very few songs have very low Danceability while having very high Valence
# No songs with very high Speechiness and very low Danceability, but also few very high/very high
# Positive correlation with loudness, altough there are songs with high Danceability & not Loud
# Seems normaloy distributed

# Duration:
# The longest songs are often around avg tempo
# Songs with high speechiness are never very long

# Energy:
# High Energy => high Loudness

# Loundness:
# High valence => not low Loudness
# Medium instrumentalness or acousticness => not low loudness
# High speechiness => not low loudness
# Higher energy => higher loudness (altough wide spread)

# %%
df.columns
# Out:
# Index(['artists', 'album_name', 'track_name', 'popularity', 'duration_ms',
#        'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
sns.scatterplot(data = df, x = 'danceability', y = 'tempo', color = 'gold')
plt.title("Danceability vs Tempo", size = 18)
plt.savefig("danceablity_tempo.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'danceability', y = 'valence', color = 'gold')
plt.title("Danceability vs Valence", size = 18)
plt.savefig("danceablity_valence.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'danceability', y = 'speechiness', color = 'gold')
plt.title("Danceability vs Speechiness", size = 18)
plt.savefig("danceablity_speechiness.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'danceability', y = 'loudness', color = 'gold')
plt.title("Danceability vs Loudness", size = 18)
plt.savefig("danceablity_loudness.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'loudness', y = 'tempo', color = 'gold')
plt.title("Loudness vs Tempo", size = 18)
plt.savefig("loudness_tempo.png", transparent = True)

plt.show()

# %%
df.columns
# Out:
# Index(['artists', 'album_name', 'track_name', 'popularity', 'duration_ms',
#        'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
sns.scatterplot(data = df, x = 'duration_ms', y = 'tempo', color = 'gold')
plt.title("Duration vs Tempo", size = 18)
plt.savefig("duration_tempo.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'duration_ms', y = 'speechiness', color = 'gold')
plt.title("Duration vs Speechiness", size = 18)
plt.savefig("duration_speechiness.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'loudness', y = 'energy', color = 'gold')
plt.title("Loudness vs Energy", size = 18)
plt.savefig("energy_loudness.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'loudness', y = 'valence', color = 'gold')
plt.title("Loudness vs Valence", size = 18)
plt.savefig("loudness_valence.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'loudness', y = 'instrumentalness', color = 'gold')
plt.title("Loudness vs Instrumentalness", size = 18)
plt.savefig("loudness_instrumentalness.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'loudness', y = 'acousticness', color = 'gold')
plt.title("Loudness vs Acousticness", size = 18)
plt.savefig("loudness_acousticness.png", transparent = True)

plt.show()

# %%
sns.scatterplot(data = df, x = 'loudness', y = 'speechiness', color = 'gold')
plt.title("Loudness vs Speechiness", size = 18)
plt.savefig("loudness_speechiness.png", transparent = True)

plt.show()

# %%
df.columns
# Out:
# Index(['artists', 'album_name', 'track_name', 'popularity', 'duration_ms',
#        'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called df

# Select the numeric columns
numeric_cols = df.select_dtypes(include='number')

# Calculate the correlation matrix
corr_matrix = numeric_cols.corr()

# Create a heatmap using Seaborn
plt.figure(figsize=(10, 8))  # Set the figure size (optional)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix", size = 20)
plt.savefig('corrmat.png', transparent = True)
plt.show()

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## Data preparation

# %%
X.columns
# Out:
# Index(['duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
X = df.select_dtypes('number')
X.drop(columns = 'popularity', inplace = True)

# %% [markdown]
# ## Setting up a pipeline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
decomp = PCA()
pipe = make_pipeline(scaler, decomp)

pipe.fit(X)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('pca', PCA())])

# %% [markdown]
# ## KMeans

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %%
scaler = StandardScaler()
decomp = PCA()
cluster = KElbowVisualizer(KMeans())

pipe = make_pipeline(scaler, decomp, cluster)
pipe.fit(X)
pipe[2].show
plt.title("K-means elbow visualization\n", size = 22)
plt.savefig('kmeans.png', transparent = True)
plt.show()

# %%
# Using PCA(0.9) since that means 90% of variance explained
# Using 6 cluster for Kmeans given the elbow analysis
# Using STandardScaler given that the data is fairly normally distributed, no significant outliers

scaler = StandardScaler()
decomp = PCA(n_components = 0.9)
cluster = KMeans(n_clusters = 6)

pipe = make_pipeline(scaler, decomp, cluster)
pipe.fit(X)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=0.9)),
#                 ('kmeans', KMeans(n_clusters=6))])

# %%
values = pipe[:2].transform(X)
pca_labels = [f"PC{idx + 1}" for idx, i in enumerate(values.T)]

df = df.join(pd.DataFrame(values, columns = pca_labels))
df["cluster"] = pipe["kmeans"].labels_

# %%
df
# Out:
#                        artists
# 0                  Gen Hoshino  \
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113995           Rainy Lullaby
# 113996           Rainy Lullaby
# 113997           Cesária Evora
# 113998        Michael W. Smith
# 113999           Cesária Evora
#
#                                                album_name
# 0                                                  Comedy  \
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# ...

# %%
df_orig = pd.read_csv("dataset.csv")
df_orig.drop(columns = ["Unnamed: 0", "track_id", "popularity"], inplace = True)

# %%
import math
import seaborn as sns
import matplotlib.pyplot as plt

var_lst = df_orig.select_dtypes("number").columns

rows = 6
cols = math.ceil(len(var_lst) / rows)

fig, axs = plt.subplots(nrows=rows, ncols=cols, figsize=(20, 5 * rows))

for i, ax in zip(var_lst, axs.flat):
    sns.barplot(data=df, x="cluster", y=i, ax=ax, palette="husl")
    ax.set(xlabel='', ylabel='', title=i)

for i in axs.flat[::-1][:rows * cols - len(var_lst)]:
    i.set_axis_off()

plt.show()

# %%
import math
import seaborn as sns
import matplotlib.pyplot as plt

var_lst = df_orig.select_dtypes("number").columns

rows = 6
cols = math.ceil(len(var_lst) / rows)

fig, axs = plt.subplots(nrows=rows, ncols=cols, figsize=(20, 5 * rows))

# Define the custom tick labels
xtick_labels = ['live recordings','Minor party', 'Party', 'Acoustic', 'Instrumental techno', 'singer_songwriter']

for i, ax in zip(var_lst, axs.flat):
    sns.barplot(data=df, x="cluster", y=i, ax=ax, palette="husl")
    ax.set(xlabel='', ylabel='', title=i)
    ax.set_xticklabels(xtick_labels, rotation=45, ha='right')

for i in axs.flat[::-1][:rows * cols - len(var_lst)]:
    i.set_axis_off()

plt.tight_layout()  # Adjust the spacing between subplots

plt.show()

# %%
df.groupby("cluster")["popularity"].mean()
# Out:
# cluster
# 0    33.872884
# 1    35.523074
# 2    33.853644
# 3    33.570914
# 4    28.250378
# 5    28.400681
# Name: popularity, dtype: float64

# %%
import matplotlib.pyplot as plt

cluster_counts = df["cluster"].value_counts()

cluster_counts.plot.bar(color = 'gold')
plt.xlabel("Cluster")
plt.ylabel("Count")
plt.title("Number of Rows per Cluster")
# Define the custom tick labels
xtick_labels = ['live recordings', 'Minor party', 'Party', 'Acoustic', 'Instrumental techno', 'singer_songwriter']

plt.gca().set_xticklabels(xtick_labels, rotation=45, ha='right')  # Adjust x-axis labels
plt.show()
plt.savefig("clustercount.png", transparent = True)

# %%
import matplotlib.pyplot as plt

mean_popularity = df.groupby("cluster")["popularity"].mean()

mean_popularity.plot.bar(color='gold')
plt.xlabel("Cluster")
plt.ylabel("Mean Popularity")
plt.title("Mean Popularity by Cluster")

# Define the custom tick labels
xtick_labels = ['live recordings', 'Minor party', 'Party', 'Acoustic', 'Instrumental techno', 'singer_songwriter']

plt.gca().set_xticklabels(xtick_labels, rotation=45, ha='right')  # Adjust x-axis labels

plt.show()
plt.savefig("cluster_popularity.png", transparent = True)
